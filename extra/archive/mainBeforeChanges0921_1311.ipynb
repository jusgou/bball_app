# %%
import pandas as pd
import matplotlib.pyplot as plt
from classes import NBATeamRosters
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
import json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 from classes import NBATeamRosters
#       4 import matplotlib.pyplot as plt
#       5 import matplotlib.dates as mdates
#
# ModuleNotFoundError: No module named 'classes'

# %%
import seaborn as sns

# %%
nba_data = NBATeamRosters(season="2024")

# %%
# Fetch the list of teams
#nba_data.fetch_teams()

# Display the teams DataFrame
#nba_data.teams_df

# %% [markdown]
# # Set Constants

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Define the previous season
previous_season = "2023-24"
current_season = "2024-25"

# %%
# Fetch Teams Master List 
nba_data.fetch_teams()
teams_df = nba_data.teams_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Fetch Teams Master List
# ----> 2 nba_data.fetch_teams()
#       3 teams_df = nba_data.teams_df
#
# NameError: name 'nba_data' is not defined

# %% [markdown]
# # Full Schedule

# %%
# Load the schedule from your CSV file
nba_data.load_schedule('nbaSchedule2425.csv')  # Replace with your actual CSV path
# Out:
# Schedule loaded: 1200 games

# %%
# Display the full schedule
schedule_df = nba_data.get_full_schedule()

# %% [markdown]
# # Today's Games

# %%
today_date = datetime.datetime.today().strftime('%Y-%m-%d')

# Retrieve today's games
todays_games = nba_data.get_todays_games("2024-10-23") # Use today_date when in season

# %% [markdown]
# # Filter Schedule By Team

# %%
team_schedule = nba_data.filter_schedule_by_team("MEM")

# %% [markdown]
# # Team Rosters

# %%
g1_home_ros = nba_data.get_team_roster("MEM")
g1_away_ros = nba_data.get_team_roster("NYK")
g2_home_ros = nba_data.get_team_roster("LAL")
g2_away_ros = nba_data.get_team_roster("MIN")
#g3_home_ros = nba_data.get_team_roster("LAL")
#g3_away_ros = nba_data.get_team_roster("MIN")
#g4_home_ros = nba_data.get_team_roster("LAL")
#g4_away_ros = nba_data.get_team_roster("MIN")
#g5_home_ros = nba_data.get_team_roster("LAL")
#g5_away_ros = nba_data.get_team_roster("MIN")
#g6_home_ros = nba_data.get_team_roster("LAL")
#g6_away_ros = nba_data.get_team_roster("MIN")
#g7_home_ros = nba_data.get_team_roster("LAL")
#g7_away_ros = nba_data.get_team_roster("MIN")
#g8_home_ros = nba_data.get_team_roster("LAL")
#g8_away_ros = nba_data.get_team_roster("MIN")
#g9_home_ros = nba_data.get_team_roster("LAL")
#g9_away_ros = nba_data.get_team_roster("MIN")
#g10_home_ros = nba_data.get_team_roster("LAL")
#g10_away_ros = nba_data.get_team_roster("MIN")
#g11_home_ros = nba_data.get_team_roster("LAL")
#g11_away_ros = nba_data.get_team_roster("MIN")

# %% [markdown]
# # Manual Game Lineups

# %%
# Manually select players for the home lineup (using PLAYER_IDs as an example)
#g1_home_player_ids = [1628369, 201950, 1627759, 204001,1628401,1630202,1630573,201143]
# Manually select players for the away lineup (using PLAYER_IDs as an example)
#g1_away_player_ids = [1628973, 1628978, 1630540, 1628384, 1628969,203944,1628404]

# %%
#home_lineup = g1_home_ros[g1_home_ros['PLAYER_ID'].isin(g1_home_player_ids)]
#away_lineup = g1_away_ros[g1_away_ros['PLAYER_ID'].isin(g1_away_player_ids)]

# %%
"""
# Initialize empty lists to store the stats DataFrames
home_lineup_stats_list = []
away_lineup_stats_list = []

# Fetch stats for each player in the home lineup
for index, player in home_lineup.iterrows():
    player_id = player['PLAYER_ID']
    player_stats = nba_data.fetch_player_career_stats(player_id)
    
    if player_stats is not None and not player_stats.empty:
        # Filter to keep only the previous season's stats
        player_stats = player_stats[player_stats['SEASON_ID'] == previous_season]
        home_lineup_stats_list.append(player_stats)

# Combine the list of DataFrames into a single DataFrame
home_lineup_stats = pd.concat(home_lineup_stats_list, ignore_index=True)

# Repeat the process for the away lineup
for index, player in away_lineup.iterrows():
    player_id = player['PLAYER_ID']
    player_stats = nba_data.fetch_player_career_stats(player_id)
    
    if player_stats is not None and not player_stats.empty:
        # Filter to keep only the previous season's stats
        player_stats = player_stats[player_stats['SEASON_ID'] == previous_season]
        away_lineup_stats_list.append(player_stats)

away_lineup_stats = pd.concat(away_lineup_stats_list, ignore_index=True)
"""
# Out:
# "\n# Initialize empty lists to store the stats DataFrames\nhome_lineup_stats_list = []\naway_lineup_stats_list = []\n\n# Fetch stats for each player in the home lineup\nfor index, player in home_lineup.iterrows():\n    player_id = player['PLAYER_ID']\n    player_stats = nba_data.fetch_player_career_stats(player_id)\n    \n    if player_stats is not None and not player_stats.empty:\n        # Filter to keep only the previous season's stats\n        player_stats = player_stats[player_stats['SEASON_ID'] == previous_season]\n        home_lineup_stats_list.append(player_stats)\n\n# Combine the list of DataFrames into a single DataFrame\nhome_lineup_stats = pd.concat(home_lineup_stats_list, ignore_index=True)\n\n# Repeat the process for the away lineup\nfor index, player in away_lineup.iterrows():\n    player_id = player['PLAYER_ID']\n    player_stats = nba_data.fetch_player_career_stats(player_id)\n    \n    if player_stats is not None and not player_stats.empty:\n        # Filter to keep only the previous season's stats\n        player_stats = player_stats[player_stats['SEASON_ID'] == previous_season]\n        away_lineup_stats_list.append(player_stats)\n\naway_lineup_stats = pd.concat(away_lineup_stats_list, ignore_index=True)\n"

# %% [markdown]
# # Import Player Career Stats for Rosters

# %%
# Initialize empty lists to store the stats DataFrames
home_lineup_stats_list = []
away_lineup_stats_list = []


# Fetch stats for each player in the home lineup
for index, player in g1_home_ros.iterrows():
    player_id = player['PLAYER_ID']
    player_stats = nba_data.fetch_player_career_stats(player_id)
    
    if player_stats is not None and not player_stats.empty:
        # Filter to keep only the previous season's stats
        player_stats = player_stats[player_stats['SEASON_ID'] == previous_season]
        
        # If there are stats for the previous season, add to the list
        if not player_stats.empty:
            home_lineup_stats_list.append(player_stats)

# Combine the list of DataFrames into a single DataFrame
home_lineup_stats = pd.concat(home_lineup_stats_list, ignore_index=True) if home_lineup_stats_list else pd.DataFrame()

# Repeat the process for the away lineup
for index, player in g1_away_ros.iterrows():
    player_id = player['PLAYER_ID']
    player_stats = nba_data.fetch_player_career_stats(player_id)
    
    if player_stats is not None and not player_stats.empty:
        # Filter to keep only the previous season's stats
        player_stats = player_stats[player_stats['SEASON_ID'] == previous_season]
        
        # If there are stats for the previous season, add to the list
        if not player_stats.empty:
            away_lineup_stats_list.append(player_stats)

# Combine the list of DataFrames into a single DataFrame
away_lineup_stats = pd.concat(away_lineup_stats_list, ignore_index=True) if away_lineup_stats_list else pd.DataFrame()

# %%
# Merge home lineup stats with home lineup to get player names
home_lineup_stats = home_lineup_stats.merge(
    g1_home_ros[['PLAYER_ID', 'PLAYER']],
    on='PLAYER_ID',
    how='left'
)

# Merge away lineup stats with away lineup to get player names
away_lineup_stats = away_lineup_stats.merge(
    g1_away_ros[['PLAYER_ID', 'PLAYER']],
    on='PLAYER_ID',
    how='left'
)

# %%
# Reorder the columns so that 'PLAYER' is the first column
columns = ['PLAYER'] + [col for col in home_lineup_stats.columns if col != 'PLAYER']
home_lineup_stats = home_lineup_stats[columns]

# Do the same for away_lineup_stats
columns = ['PLAYER'] + [col for col in away_lineup_stats.columns if col != 'PLAYER']
away_lineup_stats = away_lineup_stats[columns]

# %%
home_lineup_stats
# Out:
#                 PLAYER  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 0     Maozinha Pereira    1641970   2023-24        00  1610612763
# 1    Scotty Pippen Jr.    1630590   2023-24        00  1610612763
# 2         Jake LaRavia    1631222   2023-24        00  1610612763
# 3   Vince Williams Jr.    1631246   2023-24        00  1610612763
# 4         Santi Aldama    1630583   2023-24        00  1610612763
# 5         Luke Kennard    1628379   2023-24        00  1610612763
# 6            Ja Morant    1629630   2023-24        00  1610612763
# 7    Jaren Jackson Jr.    1628991   2023-24        00  1610612763
# 8       Brandon Clarke    1629634   2023-24        00  1610612763
# 9        Yuta Watanabe    1629139   2023-24        00  1610612756
# 10       Yuta Watanabe    1629139   2023-24        00  1610612763
# 11       Yuta Watanabe    1629139   2023-24        00           0
# 12        Desmond Bane    1630217   2023-24        00  1610612763
# 13        Derrick Rose     201565   2023-24        00  1610612763
# 14       Lamar Stevens    1630205   2023-24        00  1610612738
# 15       Lamar Stevens    1630205   2023-24        00  1610612763
# 16       Lamar Stevens    1630205   2023-24        00           0
# 17            Jay Huff    1630643   2023-24        00  1610612743
# 18        Marcus Smart     203935   2023-24        00  1610612763
# 19       GG Jackson II    1641713   2023-24        00  1610612763
# 20        John Konchar    1629723   2023-24        00  1610612763
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP  GS     MIN  FGM   FGA  FG_PCT  FG3M  \
# 0                MEM        23.0   7   1   122.0   18    35   0.514     5
# 1                MEM        23.0  21  16   527.0  100   203   0.493    30
# 2                MEM        22.0  35   6   806.0  118   303   0.389    53
# 3                MEM        23.0  52  33  1437.0  169   379   0.446    79
# 4                MEM        23.0  61  35  1618.0  247   568   0.435   106
# 5                MEM        28.0  39  22   999.0  141   315   0.448   107
# 6                MEM        24.0   9   9   318.0   80   170   0.471    14
# 7                MEM        24.0  66  66  2124.0  516  1162   0.444   117
# 8                MEM        27.0   6   1   134.0   33    59   0.559     1
# 9                PHX        29.0  29   0   382.0   35    97   0.361    24
# 10               MEM        29.0   5   0    82.0    6    19   0.316     1
# 11               TOT        29.0  34   0   464.0   41   116   0.353    25
# 12               MEM        26.0  42  42  1443.0  360   776   0.464   137
# 13               MEM        35.0  24   7   399.0   76   165   0.461    15
# 14               BOS        26.0  19   1   122.0   21    45   0.467     3
# 15               MEM        26.0  19   2   437.0   87   195   0.446    11
# 16               TOT        26.0  38   3   559.0  108   240   0.450    14
# 17               DEN        26.0  20   0    49.0    9    15   0.600     3
# 18               MEM        30.0  20  20   605.0  102   237   0.430    42
# 19               MEM        19.0  48  18  1233.0  241   563   0.428   102
# 20               MEM        28.0  55  23  1174.0   88   208   0.423    38
#
#     FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0     13    0.385    7   10   0.700    11    26   37    2    6    4    5   10
# 1     72    0.417   41   55   0.745    22    45   67   98   36   10   56   60
# 2    156    0.340   90  109   0.826    51    77  128   58   29   12   45   69
# 3    209    0.378  104  130   0.800    59   231  290  175   47   34   92  135
# 4    304    0.349   54   87   0.621    72   280  352  138   43   54   69   89
# 5    238    0.450   40   45   0.889    11   102  113  136   20    2   54   39
# 6     51    0.275   52   64   0.813     6    44   50   73    7    5   27   19
# 7    366    0.320  337  417   0.808    85   280  365  154   80  106  160  235
# 8      6    0.167    1    7   0.143    13    19   32    9    5    6    3    8
# 9     75    0.320   10   15   0.667    11    34   45   10    9    7   16   34
# 10    10    0.100    0    2   0.000     0     9    9    5    3    0    3    5
# 11    85    0.294   10   17   0.588    11    43   54   15   12    7   19   39
# 12   360    0.381  140  161   0.870    36   149  185  230   43   22  112  120
# 13    41    0.366   24   27   0.889     7    38   45   78    8    2   31   21
# 14     8    0.375    8   11   0.727    12    19   31    8    6    5    9   14
# 15    38    0.289   34   43   0.791    24    72   96   20   17   17   15   31
# 16    46    0.304   42   54   0.778    36    91  127   28   23   22   24   45
# 17     9    0.333    2    2   1.000     2     9   11    2    2    3    1    9
# 18   134    0.313   43   56   0.768     6    47   53   86   41    5   62   53
# 19   286    0.357  115  153   0.752    53   143  196   59   28   24   65   64
# 20   120    0.317   21   25   0.840    72   185  257  110   51   51   46   76
#
#      PTS
# 0     48
# 1    271
# 2    379
# 3    521
# 4    654
# 5    429
# 6    226
# 7   1486
# 8     68
# 9    104
# 10    13
# 11   117
# 12   997
# 13   191
# 14    53
# 15   219
# 16   272
# 17    23
# 18   289
# 19   699
# 20   235

# %% [markdown]
# ## Add Player Estimated Metrics

# %%
player_metrics_df = nba_data.fetch_player_estimated_metrics('2023-24')

# %% [markdown]
# # Merge Player Stats and Metrics

# %%
player_merged_df = home_lineup_stats.merge(player_metrics_df, on='PLAYER_ID', how='left')

# %%
# Keep only one set of the columns that have both _x and _y versions
player_merged_df = player_merged_df.loc[:, ~player_merged_df.columns.duplicated()]

# Step 3: (Optional) If you specifically want to drop all "_y" columns, you can do it like this
player_merged_df = player_merged_df.drop([col for col in player_merged_df.columns if '_y' in col], axis=1)

# %%
player_merged_df = player_merged_df.drop(columns=['GP_RANK','W_RANK',	'L_RANK',	'W_PCT_RANK',	'MIN_RANK',	'E_OFF_RATING_RANK',	'E_DEF_RATING_RANK',	'E_NET_RATING_RANK',	'E_AST_RATIO_RANK',	'E_OREB_PCT_RANK',	'E_DREB_PCT_RANK',	'E_REB_PCT_RANK',	'E_TOV_PCT_RANK',	'E_USG_PCT_RANK',	'E_PACE_RANK'])

# %%
player_merged_df = player_merged_df.drop(columns=['PLAYER_NAME', 'LEAGUE_ID'])

# %%
player_merged_df = player_merged_df.rename(columns={
    'GP_x': 'GP',
    'MIN_x':'MIN',
})

# %%
player_stats_complete = nba_data.convert_to_per_game_stats(player_merged_df)

# %%
player_stats_complete
# Out:
#                 PLAYER  PLAYER_ID SEASON_ID     TEAM_ID TEAM_ABBREVIATION  \
# 
# 2   27  0.229         103.5         110.3          -6.8         12.8
# 3   34  0.346         106.3         110.5          -4.2         24.9
# 4   38  0.377         104.6         113.7          -9.1         17.0
# 5   24  0.385         105.5         115.5         -10.0         25.9
# 6    3  0.667         109.9         109.7           0.2         24.5
# 7   44  0.333         104.9         112.7          -7.8          9.3
# 8    4  0.333         100.1         105.2          -5.1         12.1
# 9   16  0.529         106.8         115.2          -8.5          9.5
# 10  16  0.529         106.8         115.2          -8.5          9.5
# 11  16  0.529         106.8         115.2          -8.5          9.5
# 12  28  0.333         106.2         113.7          -7.6         19.3
# 13  18  0.250         103.6         106.3          -2.7         27.3
# 14  16  0.579         104.6         104.3           0.4          8.9
# 15  16  0.579         104.6         104.3           0.4          8.9
# 16  16  0.579         104.6         104.3           0.4          8.9
# 17   4  0.800          98.3         106.7          -8.4         10.6
# 18  13  0.350         106.8         106.6           0.2         21.0
# 19  34  0.292         103.2         111.7          -8.4          7.8
# 20  37  0.327         105.0         111.2          -6.1         29.3
#
#     E_OREB_PCT  E_DREB_PCT  E_REB_PCT  E_TOV_PCT  E_USG_PCT  E_PACE
# 0        0.086       0.230      0.154     10.776      0.149  100.70
# 1        0.043       0.097      0.068     14.690      0.232   99.85
# 2        0.065       0.108      0.086      9.913      0.205  100.97
# 3        0.044       0.185      0.112     13.083      0.158  100.49
# 4        0.047       0.199      0.119      8.484      0.181   99.55
# 5        0.012       0.119      0.065     10.290      0.172   99.86
# 6        0.021       0.153      0.088      9.056      0.305  102.22
# 7        0.042       0.151      0.094      9.647      0.306  101.39
# 8        0.088       0.174      0.125      4.050      0.195  101.35
# 9        0.027       0.098      0.064     12.065      0.133  100.06
# 10       0.027       0.098      0.064     12.065      0.133  100.06
# 11       0.027       0.098      0.064     12.065      0.133  100.06
# 12       0.026       0.117      0.070      9.421      0.280  102.51
# 13       0.019       0.103      0.060     10.844      0.227  102.30
# 14       0.067       0.169      0.118      7.601      0.220   98.62
# 15       0.067       0.169      0.118      7.601      0.220   98.62
# 16       0.067       0.169      0.118      7.601      0.220   98.62
# 17       0.045       0.191      0.121      5.297      0.155  102.06
# 18       0.011       0.083      0.047     15.135      0.228  104.71
# 19       0.045       0.128      0.086      8.617      0.241  100.36
# 20       0.065       0.187      0.123     12.267      0.098   99.76

# %% [markdown]
# ## Make Stats Per Game Stats

# %%
# Convert home and away player stats to per-game averages
home_lineup_per_game_stats = nba_data.convert_to_per_game_stats(home_lineup_stats)
away_lineup_per_game_stats = nba_data.convert_to_per_game_stats(away_lineup_stats)

# %%
home_lineup_per_game_stats
# Out:
#                 PLAYER  PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  \
# 0     Maozinha Pereira    1641970   2023-24        00  1610612763
# 1    Scotty Pippen Jr.    1630590   2023-24        00  1610612763
# 2         Jake LaRavia    1631222   2023-24        00  1610612763
# 3   Vince Williams Jr.    1631246   2023-24        00  1610612763
# 4         Santi Aldama    1630583   2023-24        00  1610612763
# 5         Luke Kennard    1628379   2023-24        00  1610612763
# 6            Ja Morant    1629630   2023-24        00  1610612763
# 6   5.67    0.275  5.78  7.11   0.813  0.67  4.89  5.56  8.11  0.78  0.56
# 7   5.55    0.320  5.11  6.32   0.808  1.29  4.24  5.53  2.33  1.21  1.61
# 8   1.00    0.167  0.17  1.17   0.143  2.17  3.17  5.33  1.50  0.83  1.00
# 9   2.59    0.320  0.34  0.52   0.667  0.38  1.17  1.55  0.34  0.31  0.24
# 10  2.00    0.100  0.00  0.40   0.000  0.00  1.80  1.80  1.00  0.60  0.00
# 11  2.50    0.294  0.29  0.50   0.588  0.32  1.26  1.59  0.44  0.35  0.21
# 12  8.57    0.381  3.33  3.83   0.870  0.86  3.55  4.40  5.48  1.02  0.52
# 13  1.71    0.366  1.00  1.12   0.889  0.29  1.58  1.88  3.25  0.33  0.08
# 14  0.42    0.375  0.42  0.58   0.727  0.63  1.00  1.63  0.42  0.32  0.26
# 15  2.00    0.289  1.79  2.26   0.791  1.26  3.79  5.05  1.05  0.89  0.89
# 16  1.21    0.304  1.11  1.42   0.778  0.95  2.39  3.34  0.74  0.61  0.58
# 17  0.45    0.333  0.10  0.10   1.000  0.10  0.45  0.55  0.10  0.10  0.15
# 18  6.70    0.313  2.15  2.80   0.768  0.30  2.35  2.65  4.30  2.05  0.25
# 19  5.96    0.357  2.40  3.19   0.752  1.10  2.98  4.08  1.23  0.58  0.50
# 20  2.18    0.317  0.38  0.45   0.840  1.31  3.36  4.67  2.00  0.93  0.93
#
#      TOV    PF    PTS
# 0   0.71  1.43   6.86
# 1   2.67  2.86  12.90
# 2   1.29  1.97  10.83
# 3   1.77  2.60  10.02
# 4   1.13  1.46  10.72
# 5   1.38  1.00  11.00
# 6   3.00  2.11  25.11
# 7   2.42  3.56  22.52
# 8   0.50  1.33  11.33
# 9   0.55  1.17   3.59
# 10  0.60  1.00   2.60
# 11  0.56  1.15   3.44
# 12  2.67  2.86  23.74
# 13  1.29  0.88   7.96
# 14  0.47  0.74   2.79
# 15  0.79  1.63  11.53
# 16  0.63  1.18   7.16
# 17  0.05  0.45   1.15
# 18  3.10  2.65  14.45
# 19  1.35  1.33  14.56
# 20  0.84  1.38   4.27

# %% [markdown]
# # Team Stats

# %%
g1_home_tstats = nba_data.fetch_team_stats("BOS", season="2023-24")
g1_away_tstats = nba_data.fetch_team_stats("NYK", season="2023-24")

# %%
# List of columns to drop
columns_to_drop = ['GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 
                   'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 
                   'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK', 
                   'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK']

# Drop the specified columns
g1_home_tstats = g1_home_tstats.drop(columns=columns_to_drop)

# %%
team_metrics_df = nba_data.fetch_team_estimated_metrics('2023-24')

# %%
merged_df = g1_home_tstats.merge(team_metrics_df, on='TEAM_ID', how='left')

# %%
# Step 1: Reorder columns to move TEAM_ID and TEAM_NAME to the leftmost side
columns = list(merged_df.columns)  # Get a list of all column names

# Move TEAM_ID and TEAM_NAME_x (or TEAM_NAME_y, if preferred) to the front
columns = ['TEAM_ID', 'TEAM_NAME_x'] + [col for col in columns if col not in ['TEAM_ID', 'TEAM_NAME_x', 'TEAM_NAME_y']]

# Reorder the DataFrame
merged_df = merged_df[columns]

# Step 2: Drop duplicate columns (_x and _y columns)
# Keep only one set of the columns that have both _x and _y versions
merged_df = merged_df.loc[:, ~merged_df.columns.duplicated()]

# Step 3: (Optional) If you specifically want to drop all "_y" columns, you can do it like this
merged_df = merged_df.drop([col for col in merged_df.columns if '_y' in col], axis=1)
merged_df = merged_df.drop(columns=['GROUP_SET','GROUP_VALUE'])

# %%
merged_df = merged_df.rename(columns={
    'TEAM_NAME_x': 'TEAM_NAME',
    'GP_x': 'GP',
    'W_x': 'W',
    'L_x': 'L',
    'W_PCT_x':'W_PCT',
    'MIN_x':'MIN',
})

# %%
merged_df
# Out:
#       TEAM_ID       TEAM_NAME SEASON_YEAR  GP   W   L  W_PCT     MIN   FGM  \
# 0  1610612738  Boston Celtics     2023-24  82  64  18   0.78  3966.0  3601
#
#     FGA  FG_PCT  FG3M  FG3A  FG3_PCT   FTM   FTA  FT_PCT  OREB  DREB   REB  \
# 0  7396   0.487  1351  3482    0.388  1334  1654   0.807   876  2923  3799
#
#     AST    TOV  STL  BLK  BLKA    PF   PFD   PTS  PLUS_MINUS  E_OFF_RATING  \
# 0  2207  979.0  557  538   304  1326  1416  9887       930.0         120.2
#
#    E_DEF_RATING  E_NET_RATING  E_PACE  E_AST_RATIO  E_OREB_PCT  E_DREB_PCT  \
# 0         109.0          11.2    99.5         19.3       0.249       0.763
#
#    E_REB_PCT  E_TM_TOV_PCT  GP_RANK  W_RANK  L_RANK  W_PCT_RANK  MIN_RANK  \
# 0      0.517         0.119        1       1       1           1         7
#
#    E_OFF_RATING_RANK  E_DEF_RATING_RANK  E_NET_RATING_RANK  E_AST_RATIO_RANK  \
# 0                  1                  3                  1                13
#
#    E_OREB_PCT_RANK  E_DREB_PCT_RANK  E_REB_PCT_RANK  E_TM_TOV_PCT_RANK  \
# 0               12               11               4                  1
#
#    E_PACE_RANK
# 0           21

# %% [markdown]
# # Get Opponent Points Against

# %%
# Example usage
team_id = 1610612739  # Replace with your specific Team ID
season = "2023-24"
team_season_ranks_df = fetch_team_season_ranks(team_id, season)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 4
#       2 team_id = 1610612739  # Replace with your specific Team ID
#       3 season = "2023-24"
# ----> 4 team_season_ranks_df = fetch_team_season_ranks(team_id, season)
#
# NameError: name 'fetch_team_season_ranks' is not defined

# %%
team_season_ranks_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 team_season_ranks_df
#
# NameError: name 'team_season_ranks_df' is not defined

# %% [markdown]
# # Calculate Additional Advanced Statistics

# %% [markdown]
# ## Calculate PER

# %%
home_lineup_per_game_stats['PER'] = home_lineup_per_game_stats.apply(
    lambda row: calculate_player_per(row, home_team_metrics), axis=1
)

# %% [markdown]
# ## AST%

# %%
home_lineup_per_game_stats['AST%'] = home_lineup_per_game_stats.apply(
    lambda row: calculate_ast_percentage(row, home_team_metrics), axis=1
)

# %% [markdown]
# ## PIE

# %%
"""
home_lineup_per_game_stats['PIE'] = home_lineup_per_game_stats.apply(
    lambda row: calculate_pie(row, home_team_metrics, away_team_metrics), axis=1
)
"""

# %% [markdown]
# ## BPM

# %%
home_lineup_per_game_stats['BPM'] = home_lineup_per_game_stats.apply(
    lambda row: calculate_bpm(row, home_team_metrics, home_team_metrics), axis=1
)

# %% [markdown]
# # Single Player Stats Analyzer

# %%
tatum_stats = nba_data.fetch_player_career_stats(1628369)

# %%
tatum_logs = nba_data.fetch_player_game_logs(1628369,"2023")

# %%
# Ensure that GAME_DATE is in datetime format
tatum_logs['GAME_DATE'] = pd.to_datetime(tatum_logs['GAME_DATE'])

# Plotting the time series of PTS
plt.figure(figsize=(10, 6))
plt.plot(tatum_logs['GAME_DATE'], tatum_logs['PTS'], marker='o', color='b', label='Points per Game')
plt.axhline(tatum_logs['PTS'].mean(), color='r', linestyle='--', label='Average Points')

# Adding labels and title
plt.title('Jayson Tatum Points per Game - 2023-2024 Season')
plt.xlabel('Game Date')
plt.ylabel('Points')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\justi\AppData\Local\Temp\ipykernel_43792\3887499708.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   tatum_logs['GAME_DATE'] = pd.to_datetime(tatum_logs['GAME_DATE'])

# %% [markdown]
# ### Standard Deviation, Variance, and Distribution Analysis

# %%
# Calculate mean, variance, and standard deviation
mean_pts = tatum_logs['PTS'].mean()
variance_pts = tatum_logs['PTS'].var()
std_dev_pts = tatum_logs['PTS'].std()

# Calculate the z-scores for each game
tatum_logs['Z_SCORE'] = (tatum_logs['PTS'] - mean_pts) / std_dev_pts

# Define the ranges for standard deviations
std_dev_ranges = [
    (0, 0.5),
    (0.501, 1),
    (1.01, 1.5),
    (1.501, 2),
    (2.01, 2.5),
    (2.501, 3)
]

# Calculate the frequency of games within each standard deviation range
freq_within_std_dev = {
    f'Between {low} SD and {high} SD': tatum_logs[
        (tatum_logs['Z_SCORE'].abs() > low) & (tatum_logs['Z_SCORE'].abs() <= high)
    ].shape[0]
    for low, high in std_dev_ranges
}

# Display the frequency of games within standard deviations
freq_df = pd.DataFrame(list(freq_within_std_dev.items()), columns=['Range', 'Games Count'])
freq_df
# Out:
#                         Range  Games Count
# 0     Between 0 SD and 0.5 SD           30
# 1   Between 0.501 SD and 1 SD           22
# 2  Between 1.01 SD and 1.5 SD           12
# 3   Between 1.501 SD and 2 SD            6
# 4  Between 2.01 SD and 2.5 SD            0
# 5   Between 2.501 SD and 3 SD            3

# %%
# Plotting the distribution
plt.figure(figsize=(10, 6))
sns.histplot(tatum_logs['PTS'], kde=True, color='b')
plt.axvline(mean_pts, color='r', linestyle='--', label=f'Average Points = {mean_pts:.2f}')
plt.axvline(mean_pts + std_dev_pts, color='g', linestyle='--', label=f'+1 SD = {mean_pts + std_dev_pts:.2f}')
plt.axvline(mean_pts - std_dev_pts, color='g', linestyle='--', label=f'-1 SD = {mean_pts - std_dev_pts:.2f}')
plt.axvline(mean_pts + 2 * std_dev_pts, color='orange', linestyle='--', label=f'+2 SD = {mean_pts + 2 * std_dev_pts:.2f}')
plt.axvline(mean_pts - 2 * std_dev_pts, color='orange', linestyle='--', label=f'-2 SD = {mean_pts - 2 * std_dev_pts:.2f}')

# Adding labels and title
plt.title('Distribution of Jayson Tatum's Points per Game - 2023-2024 Season')
plt.xlabel('Points')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#   Cell In[96], line 11
#     plt.title('Distribution of Jayson Tatum's Points per Game - 2023-2024 Season')
#                                                                                 ^
# SyntaxError: unterminated string literal (detected at line 11)

# %% [markdown]
# ## PPG Trend

# %%
# Assuming tatum_logs contains Tatum's game logs with a 'PTS' column and a 'GAME_DATE' column
tatum_logs['GAME_DATE'] = pd.to_datetime(tatum_logs['GAME_DATE'])

# Sort by game date to ensure the plot is chronological
tatum_logs.sort_values('GAME_DATE', inplace=True)

# Calculate the moving average (e.g., 5-game moving average)
tatum_logs['MOVING_AVG_PPG'] = tatum_logs['PTS'].rolling(window=5).mean()

# Plotting the PPG trend
plt.figure(figsize=(12, 6))
plt.plot(tatum_logs['GAME_DATE'], tatum_logs['PTS'], marker='o', linestyle='-', label='Points Per Game', color='b')
plt.plot(tatum_logs['GAME_DATE'], tatum_logs['MOVING_AVG_PPG'], linestyle='-', label='5-Game Moving Average', color='orange')
plt.axhline(mean_pts, color='r', linestyle='--', label=f'Average PPG = {mean_pts:.2f}')

# Highlight high-scoring streaks (e.g., games where he scored above his average PPG)
high_scoring_streaks = tatum_logs[tatum_logs['PTS'] > mean_pts]
plt.scatter(high_scoring_streaks['GAME_DATE'], high_scoring_streaks['PTS'], color='green', label='Above Average PPG')

# Highlight low-scoring streaks (e.g., games where he scored below his average PPG)
low_scoring_streaks = tatum_logs[tatum_logs['PTS'] < mean_pts]
plt.scatter(low_scoring_streaks['GAME_DATE'], low_scoring_streaks['PTS'], color='red', label='Below Average PPG')

# Adding labels and title
plt.title("Jayson Tatum's Points Per Game Trend - 2023-2024 Season")
plt.xlabel('Game Date')
plt.ylabel('Points')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Player Matchup Comparison

# %%
home_lineup_stats
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 home_lineup_stats
#
# NameError: name 'home_lineup_stats' is not defined

# %%
away_lineup

# %%
home_player_id = 1628369  # Jayson Tatum's player ID
away_player_id = 1628969  # Example: Another player's ID from the away team

# %%
# Fetch the game logs for both players
home_player_logs = nba_data.fetch_player_game_logs(home_player_id, '2023-24')
away_player_logs = nba_data.fetch_player_game_logs(away_player_id, '2023-24')

# %%
# Calculate the moving average for points per game for both players
home_player_logs['MOVING_AVG_PPG'] = home_player_logs['PTS'].rolling(window=5).mean()
away_player_logs['MOVING_AVG_PPG'] = away_player_logs['PTS'].rolling(window=5).mean()

# %%
plt.figure(figsize=(12, 6))

# Plotting the home player's PPG trend with markers
plt.plot(home_player_logs['GAME_DATE'], home_player_logs['MOVING_AVG_PPG'], label='Home Player - 5-Game Moving Average', color='blue', marker='o')

# Plotting the away player's PPG trend with markers
plt.plot(away_player_logs['GAME_DATE'], away_player_logs['MOVING_AVG_PPG'], label='Away Player - 5-Game Moving Average', color='red', marker='o')

# Formatting the x-axis dates
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
plt.gca().xaxis.set_major_locator(mdates.WeekdayLocator(interval=1))
plt.gcf().autofmt_xdate()  # Rotate date labels

# Adding labels and title
plt.title('Head-to-Head Comparison of Points Per Game - 2023-2024 Season')
plt.xlabel('Game Date')
plt.ylabel('Points Per Game (Moving Average)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Get opponent stats from team game logs to build score predictor
# # import the betting tables to predict whether the over/under will hit for total points
# # Same for the spread
# # then focus on machine learning on player stats and opponent matchups to predict individual player statistics (use these also to factor into the totals (or build 2 models and see which predicts better))
# # Need to find stats from opponents to really make this swing, so look at nba.com or anywhere else to bolster these statistics.
